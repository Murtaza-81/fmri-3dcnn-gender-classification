# %%
import numpy as np
import json

X = np.load("prepared_data/X_train.npy")

print("Shape:", X.shape)
print("Dtype:", X.dtype)
print("Min:", X.min())
print("Max:", X.max())
print("NaNs:", np.isnan(X).sum())

with open("prepared_data/dataset_info.json") as f:
    info = json.load(f)

print(info)
# Out:
# Shape: (147, 64, 64, 34)
# Dtype: float32
# Min: -1.0
# Max: 1.0
# NaNs: 0
# {'total_samples': 184, 'train_samples': 147, 'test_samples': 37, 'input_shape': [184, 64, 64, 34], 'target_shape': [64, 64, 34], 'data_type': 'fMRI (resting-state)', 'normalization': 'Min-Max to [-1, 1]', 'gender_distribution': {'male': 80, 'female': 104}, 'age_range': [18, 76]}

# %%
import os

for root, dirs, files in os.walk("prepared_data"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# prepared_data\dataset_info.json
# prepared_data\test_metadata.json
# prepared_data\train_metadata.json
# prepared_data\X_test.npy
# prepared_data\X_train.npy

# %%
import numpy as np

X = np.load("prepared_data/X_train.npy")

print("Shape:", X.shape)
# Out:
# Shape: (147, 64, 64, 34)

# %%
import numpy as np

X_train = np.load("prepared_data/X_train.npy")
X_test = np.load("prepared_data/X_test.npy")

print("Train Shape:", X_train.shape)
print("Test Shape:", X_test.shape)

print("Train dtype:", X_train.dtype)

print("Train min:", X_train.min())
print("Train max:", X_train.max())

print("NaNs:", np.isnan(X_train).sum())
# Out:
# Train Shape: (147, 64, 64, 34)
# Test Shape: (37, 64, 64, 34)
# Train dtype: float32
# Train min: -1.0
# Train max: 1.0
# NaNs: 0
